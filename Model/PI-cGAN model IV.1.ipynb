# %%
import os
import glob
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
from IPython.display import clear_output
from tqdm.notebook import tqdm
from skimage.metrics import structural_similarity as ssim_metric

# ⚠️ 確保已經安裝 pytorch-msssim
try:
    from pytorch_msssim import ms_ssim
except ImportError:
    raise ImportError("請先在另一個 Cell 執行: !pip install pytorch-msssim")

# ==========================================
# 1. 環境設定與資料載入
# ==========================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"目前使用的運算裝置: {device}")

class DeepSpaceDataset(Dataset):
    def __init__(self, npz_folder):
        self.inputs = []
        self.targets = []
        file_paths = glob.glob(os.path.join(npz_folder, "*.npz"))
        for f in file_paths:
            data = np.load(f)
            self.inputs.append(data['inputs'])
            self.targets.append(data['targets'])
        self.inputs = np.concatenate(self.inputs, axis=0)
        self.targets = np.concatenate(self.targets, axis=0)
        self.inputs = np.expand_dims(self.inputs, axis=1)
        self.targets = np.expand_dims(self.targets, axis=1)

    def __len__(self):
        return self.inputs.shape[0]

    def __getitem__(self, idx):
        x = torch.tensor(self.inputs[idx], dtype=torch.float32)
        y = torch.tensor(self.targets[idx], dtype=torch.float32)
        x = (x - 0.5) / 0.55
        y = (y - 0.5) / 0.55
        x = torch.clamp(x, -1.0, 1.0)
        y = torch.clamp(y, -1.0, 1.0)
        return x, y

DATA_DIR = "processed_dataset"
full_dataset = DeepSpaceDataset(DATA_DIR)

dataset_size = len(full_dataset)
test_size = int(0.2 * dataset_size)
train_size = dataset_size - test_size

train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size], generator=torch.Generator().manual_seed(42))
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, drop_last=True)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False, drop_last=False)

# ==========================================
# 2. 神經網路架構
# ==========================================
class UNetDown(nn.Module):
    def __init__(self, in_channels, out_channels, normalize=True, dropout=0.0):
        super().__init__()
        layers = [nn.Conv2d(in_channels, out_channels, kernel_size=4, stride=2, padding=1, bias=False)]
        if normalize:
            layers.append(nn.BatchNorm2d(out_channels))
        layers.append(nn.LeakyReLU(0.2))
        if dropout > 0.0:
            layers.append(nn.Dropout(dropout))
        self.model = nn.Sequential(*layers)
    def forward(self, x): return self.model(x)

class UNetUp(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=0.0):
        super().__init__()
        layers = [
            nn.ConvTranspose2d(in_channels, out_channels, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        ]
        if dropout > 0.0:
            layers.append(nn.Dropout(dropout))
        self.model = nn.Sequential(*layers)
    def forward(self, x, skip_input):
        x = self.model(x)
        return torch.cat((x, skip_input), 1)

class GeneratorUNet(nn.Module):
    def __init__(self, in_channels=1, out_channels=1):
        super().__init__()
        self.down1 = UNetDown(in_channels, 64, normalize=False)
        self.down2 = UNetDown(64, 128)
        self.down3 = UNetDown(128, 256)
        self.down4 = UNetDown(256, 512, dropout=0.5)
        self.down5 = UNetDown(512, 512, dropout=0.5)
        self.up1 = UNetUp(512, 512, dropout=0.5)
        self.up2 = UNetUp(1024, 256)
        self.up3 = UNetUp(512, 128)
        self.up4 = UNetUp(256, 64)
        self.final = nn.Sequential(nn.ConvTranspose2d(128, out_channels, kernel_size=4, stride=2, padding=1), nn.Tanh())
    def forward(self, x):
        d1 = self.down1(x)
        d2 = self.down2(d1)
        d3 = self.down3(d2)
        d4 = self.down4(d3)
        d5 = self.down5(d4)
        u1 = self.up1(d5, d4)
        u2 = self.up2(u1, d3)
        u3 = self.up3(u2, d2)
        u4 = self.up4(u3, d1)
        return self.final(u4)

class Discriminator(nn.Module):
    def __init__(self, in_channels=1):
        super().__init__()
        def discriminator_block(in_filters, out_filters, normalization=True):
            layers = [nn.Conv2d(in_filters, out_filters, 4, stride=2, padding=1)]
            if normalization: layers.append(nn.BatchNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers
        self.model = nn.Sequential(
            *discriminator_block(in_channels * 2, 64, normalization=False),
            *discriminator_block(64, 128),
            *discriminator_block(128, 256),
            *discriminator_block(256, 512),
            nn.Conv2d(512, 1, 4, padding=1, bias=False)
        )
    def forward(self, img_A, img_B):
        img_input = torch.cat((img_A, img_B), 1)
        return self.model(img_input)

# ==========================================
# 3. 物理引擎 V3 (最穩定的線性物理域)
# ==========================================
class PhysicsInformedLossV3(nn.Module):
    # 🌟 微調 1：稍微調高 lambda_flux，讓物理約束更強 (原0.01 -> 0.5)
    def __init__(self, lambda_pixel=100, lambda_fft=0.1, lambda_flux=0.5, asinh_a=0.1): 
        super().__init__()
        self.lambda_pixel = lambda_pixel
        self.lambda_fft = lambda_fft
        self.lambda_flux = lambda_flux
        self.criterion_l1 = nn.L1Loss()
        self.a = asinh_a
        self.arcsinh_1_over_a = np.arcsinh(1.0 / self.a)

    def inverse_transform_to_linear(self, tensor_img):
        y_original = (tensor_img * 0.55) + 0.5
        y_clamped = torch.clamp(y_original, 0.0, 1.0)
        return self.a * torch.sinh(y_clamped * self.arcsinh_1_over_a)

    def forward(self, generated, target):
        gen_linear = self.inverse_transform_to_linear(generated)
        target_linear = self.inverse_transform_to_linear(target)

        loss_pixel = self.criterion_l1(gen_linear, target_linear)
        
        fft_gen = torch.fft.fft2(generated, norm="ortho")
        fft_target = torch.fft.fft2(target, norm="ortho")
        loss_fft_real = self.criterion_l1(torch.real(fft_gen), torch.real(fft_target))
        loss_fft_imag = self.criterion_l1(torch.imag(fft_gen), torch.imag(fft_target))
        loss_fft = loss_fft_real + loss_fft_imag

        star_mask = (target > 0.0).float().detach() 
        flux_gen = torch.sum(gen_linear * star_mask, dim=(2, 3))
        flux_target = torch.sum(target_linear * star_mask, dim=(2, 3))
        loss_flux = self.criterion_l1(flux_gen, flux_target)

        total_pi_loss = (self.lambda_pixel * loss_pixel) + (self.lambda_fft * loss_fft) + (self.lambda_flux * loss_flux)
        return total_pi_loss, loss_pixel, loss_fft, loss_flux

# ==========================================
# 4. V4.1 微調環境設定 & 載入 V3 權重
# ==========================================
OUTPUT_V4_1_DIR = "PI_cGAN_V4_1_Balanced_results"
os.makedirs(OUTPUT_V4_1_DIR, exist_ok=True)
print(f"📁 已建立/確認 V4.1 專屬資料夾：{OUTPUT_V4_1_DIR}")

generator_v4 = GeneratorUNet().to(device)
discriminator_v4 = Discriminator().to(device)

BEST_V3_WEIGHTS = "PI_cGAN_V3_Ultimate_results/picgan_ep120_weights.pth"
print(f"🧬 載入 V3 MVP 權重：{BEST_V3_WEIGHTS}")
generator_v4.load_state_dict(torch.load(BEST_V3_WEIGHTS, map_location=device))

LR_V4 = 0.00002  
optimizer_G_v4 = optim.Adam(generator_v4.parameters(), lr=LR_V4, betas=(0.5, 0.999))
optimizer_D_v4 = optim.Adam(discriminator_v4.parameters(), lr=LR_V4, betas=(0.5, 0.999))

# 這裡呼叫剛剛微調過 flux 權重的引擎
pi_criterion_v4 = PhysicsInformedLossV3().to(device)
criterion_GAN_v4 = nn.BCEWithLogitsLoss().to(device)

# ==========================================
# 5. V4.1 終極微調訓練迴圈
# ==========================================
epochs_v4 = 100
best_val_ssim = 0.0
patience = 20
no_improve_count = 0

print("🔥 V4.1 權重平衡版正式啟動：降低 SSIM 氣焰，提升 Flux 權威！")

for epoch in range(epochs_v4):
    generator_v4.train()
    discriminator_v4.train()
    epoch_ms_ssim_loss = 0.0
    
    for i, (real_A, real_B) in enumerate(train_dataloader):
        real_A, real_B = real_A.to(device), real_B.to(device)

        # Generator
        optimizer_G_v4.zero_grad()
        fake_B = generator_v4(real_A)
        
        pred_fake = discriminator_v4(real_A, fake_B)
        loss_GAN = criterion_GAN_v4(pred_fake, torch.ones_like(pred_fake, device=device))
        
        # 物理約束
        total_pi_loss, _, _, _ = pi_criterion_v4(fake_B, real_B)
        
        # MS-SSIM Loss
        gen_01 = (fake_B + 1.0) / 2.0
        real_01 = (real_B + 1.0) / 2.0
        loss_msssim = 1 - ms_ssim(gen_01, real_01, data_range=1.0, size_average=True)
        
        # 🌟 微調 2：降低 MS-SSIM 的權重 (原 50 -> 15)，讓它不要破壞物理守恆
        loss_G = loss_GAN + total_pi_loss + (15 * loss_msssim)
        loss_G.backward()
        optimizer_G_v4.step()
        
        epoch_ms_ssim_loss += loss_msssim.item()

        # Discriminator
        optimizer_D_v4.zero_grad()
        pred_real = discriminator_v4(real_A, real_B)
        loss_real = criterion_GAN_v4(pred_real, torch.ones_like(pred_real))
        pred_fake_detach = discriminator_v4(real_A, fake_B.detach())
        loss_fake = criterion_GAN_v4(pred_fake_detach, torch.zeros_like(pred_fake_detach))
        loss_D = 0.5 * (loss_real + loss_fake)
        loss_D.backward()
        optimizer_D_v4.step()

    # ---------- 驗證階段 ----------
    generator_v4.eval()
    val_ssim_list = []
    
    with torch.no_grad():
        for test_A, test_B in test_dataloader:
            test_A, test_B = test_A.to(device), test_B.to(device)
            test_fake_B = generator_v4(test_A)
            
            np_fake = test_fake_B.cpu().numpy()
            np_real = test_B.cpu().numpy()
            for b in range(np_fake.shape[0]):
                val_ssim_list.append(ssim_metric(np_real[b, 0], np_fake[b, 0], data_range=2.0))
                
        current_epoch_ssim = np.mean(val_ssim_list)
    
    print(f"Epoch [{epoch+1}/{epochs_v4}] | MS-SSIM Loss: {epoch_ms_ssim_loss/len(train_dataloader):.4f} | Validation SSIM: {current_epoch_ssim:.4f}")
    
    if current_epoch_ssim > best_val_ssim:
        best_val_ssim = current_epoch_ssim
        no_improve_count = 0
        
        best_pth_path = os.path.join(OUTPUT_V4_1_DIR, "v4_1_best_finetuned_weights.pth")
        torch.save(generator_v4.state_dict(), best_pth_path)
        
        best_npz_path = os.path.join(OUTPUT_V4_1_DIR, "v4_1_best_test_data.npz")
        test_A_sample, test_B_sample = next(iter(test_dataloader))
        test_fake_sample = generator_v4(test_A_sample.to(device))
        np.savez_compressed(best_npz_path, 
                            inputs=test_A_sample.cpu().numpy(), 
                            targets=test_B_sample.cpu().numpy(), 
                            generated=test_fake_sample.detach().cpu().numpy())
        
        print(f"   🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 {OUTPUT_V4_1_DIR}")
    else:
        no_improve_count += 1
        print(f"   ⚠️ SSIM 未突破 (目前最佳: {best_val_ssim:.4f})，停滯計數: {no_improve_count}/{patience}")
        
    if no_improve_count >= patience:
        print(f"\n🛑 觸發早停！連續 {patience} 圈未突破，微調結束。")
        break

print(f"\n🎉 V4.1 訓練大功告成！最佳成果已儲存在 {OUTPUT_V4_1_DIR}/v4_1_best_test_data.npz")
# Out:
# 目前使用的運算裝置: cuda
# 📁 已建立/確認 V4.1 專屬資料夾：PI_cGAN_V4_1_Balanced_results
# 🧬 載入 V3 MVP 權重：PI_cGAN_V3_Ultimate_results/picgan_ep120_weights.pth
# 🔥 V4.1 權重平衡版正式啟動：降低 SSIM 氣焰，提升 Flux 權威！
# Epoch [1/100] | MS-SSIM Loss: 0.1892 | Validation SSIM: 0.5393
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [2/100] | MS-SSIM Loss: 0.1879 | Validation SSIM: 0.5426
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [3/100] | MS-SSIM Loss: 0.1910 | Validation SSIM: 0.5461
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [4/100] | MS-SSIM Loss: 0.1940 | Validation SSIM: 0.5441
#    ⚠️ SSIM 未突破 (目前最佳: 0.5461)，停滯計數: 1/20
# Epoch [5/100] | MS-SSIM Loss: 0.1993 | Validation SSIM: 0.5455
#    ⚠️ SSIM 未突破 (目前最佳: 0.5461)，停滯計數: 2/20
# Epoch [6/100] | MS-SSIM Loss: 0.2022 | Validation SSIM: 0.5452
#    ⚠️ SSIM 未突破 (目前最佳: 0.5461)，停滯計數: 3/20
# Epoch [7/100] | MS-SSIM Loss: 0.2018 | Validation SSIM: 0.5486
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [8/100] | MS-SSIM Loss: 0.2014 | Validation SSIM: 0.5466
#    ⚠️ SSIM 未突破 (目前最佳: 0.5486)，停滯計數: 1/20
# Epoch [9/100] | MS-SSIM Loss: 0.1993 | Validation SSIM: 0.5439
#    ⚠️ SSIM 未突破 (目前最佳: 0.5486)，停滯計數: 2/20
# Epoch [10/100] | MS-SSIM Loss: 0.1959 | Validation SSIM: 0.5480
#    ⚠️ SSIM 未突破 (目前最佳: 0.5486)，停滯計數: 3/20
# Epoch [11/100] | MS-SSIM Loss: 0.1952 | Validation SSIM: 0.5474
#    ⚠️ SSIM 未突破 (目前最佳: 0.5486)，停滯計數: 4/20
# Epoch [12/100] | MS-SSIM Loss: 0.1945 | Validation SSIM: 0.5457
#    ⚠️ SSIM 未突破 (目前最佳: 0.5486)，停滯計數: 5/20
# Epoch [13/100] | MS-SSIM Loss: 0.1912 | Validation SSIM: 0.5509
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [14/100] | MS-SSIM Loss: 0.1889 | Validation SSIM: 0.5487
#    ⚠️ SSIM 未突破 (目前最佳: 0.5509)，停滯計數: 1/20
# Epoch [15/100] | MS-SSIM Loss: 0.1884 | Validation SSIM: 0.5478
#    ⚠️ SSIM 未突破 (目前最佳: 0.5509)，停滯計數: 2/20
# Epoch [16/100] | MS-SSIM Loss: 0.1860 | Validation SSIM: 0.5491
#    ⚠️ SSIM 未突破 (目前最佳: 0.5509)，停滯計數: 3/20
# Epoch [17/100] | MS-SSIM Loss: 0.1844 | Validation SSIM: 0.5492
#    ⚠️ SSIM 未突破 (目前最佳: 0.5509)，停滯計數: 4/20
# Epoch [18/100] | MS-SSIM Loss: 0.1834 | Validation SSIM: 0.5517
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [19/100] | MS-SSIM Loss: 0.1826 | Validation SSIM: 0.5538
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [20/100] | MS-SSIM Loss: 0.1815 | Validation SSIM: 0.5579
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [21/100] | MS-SSIM Loss: 0.1812 | Validation SSIM: 0.5553
#    ⚠️ SSIM 未突破 (目前最佳: 0.5579)，停滯計數: 1/20
# Epoch [22/100] | MS-SSIM Loss: 0.1805 | Validation SSIM: 0.5580
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [23/100] | MS-SSIM Loss: 0.1798 | Validation SSIM: 0.5603
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [24/100] | MS-SSIM Loss: 0.1800 | Validation SSIM: 0.5590
#    ⚠️ SSIM 未突破 (目前最佳: 0.5603)，停滯計數: 1/20
# Epoch [25/100] | MS-SSIM Loss: 0.1802 | Validation SSIM: 0.5587
#    ⚠️ SSIM 未突破 (目前最佳: 0.5603)，停滯計數: 2/20
# Epoch [26/100] | MS-SSIM Loss: 0.1786 | Validation SSIM: 0.5616
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [27/100] | MS-SSIM Loss: 0.1775 | Validation SSIM: 0.5649
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [28/100] | MS-SSIM Loss: 0.1773 | Validation SSIM: 0.5651
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [29/100] | MS-SSIM Loss: 0.1773 | Validation SSIM: 0.5634
#    ⚠️ SSIM 未突破 (目前最佳: 0.5651)，停滯計數: 1/20
# Epoch [30/100] | MS-SSIM Loss: 0.1770 | Validation SSIM: 0.5657
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [31/100] | MS-SSIM Loss: 0.1768 | Validation SSIM: 0.5657
#    ⚠️ SSIM 未突破 (目前最佳: 0.5657)，停滯計數: 1/20
# Epoch [32/100] | MS-SSIM Loss: 0.1754 | Validation SSIM: 0.5685
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [33/100] | MS-SSIM Loss: 0.1755 | Validation SSIM: 0.5696
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [34/100] | MS-SSIM Loss: 0.1749 | Validation SSIM: 0.5680
#    ⚠️ SSIM 未突破 (目前最佳: 0.5696)，停滯計數: 1/20
# Epoch [35/100] | MS-SSIM Loss: 0.1753 | Validation SSIM: 0.5697
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [36/100] | MS-SSIM Loss: 0.1751 | Validation SSIM: 0.5713
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [37/100] | MS-SSIM Loss: 0.1741 | Validation SSIM: 0.5697
#    ⚠️ SSIM 未突破 (目前最佳: 0.5713)，停滯計數: 1/20
# Epoch [38/100] | MS-SSIM Loss: 0.1743 | Validation SSIM: 0.5701
#    ⚠️ SSIM 未突破 (目前最佳: 0.5713)，停滯計數: 2/20
# Epoch [39/100] | MS-SSIM Loss: 0.1745 | Validation SSIM: 0.5680
#    ⚠️ SSIM 未突破 (目前最佳: 0.5713)，停滯計數: 3/20
# Epoch [40/100] | MS-SSIM Loss: 0.1743 | Validation SSIM: 0.5675
#    ⚠️ SSIM 未突破 (目前最佳: 0.5713)，停滯計數: 4/20
# Epoch [41/100] | MS-SSIM Loss: 0.1742 | Validation SSIM: 0.5702
#    ⚠️ SSIM 未突破 (目前最佳: 0.5713)，停滯計數: 5/20
# Epoch [42/100] | MS-SSIM Loss: 0.1744 | Validation SSIM: 0.5705
#    ⚠️ SSIM 未突破 (目前最佳: 0.5713)，停滯計數: 6/20
# Epoch [43/100] | MS-SSIM Loss: 0.1747 | Validation SSIM: 0.5704
#    ⚠️ SSIM 未突破 (目前最佳: 0.5713)，停滯計數: 7/20
# Epoch [44/100] | MS-SSIM Loss: 0.1736 | Validation SSIM: 0.5698
#    ⚠️ SSIM 未突破 (目前最佳: 0.5713)，停滯計數: 8/20
# Epoch [45/100] | MS-SSIM Loss: 0.1748 | Validation SSIM: 0.5722
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [46/100] | MS-SSIM Loss: 0.1745 | Validation SSIM: 0.5717
#    ⚠️ SSIM 未突破 (目前最佳: 0.5722)，停滯計數: 1/20
# Epoch [47/100] | MS-SSIM Loss: 0.1748 | Validation SSIM: 0.5719
#    ⚠️ SSIM 未突破 (目前最佳: 0.5722)，停滯計數: 2/20
# Epoch [48/100] | MS-SSIM Loss: 0.1742 | Validation SSIM: 0.5714
#    ⚠️ SSIM 未突破 (目前最佳: 0.5722)，停滯計數: 3/20
# Epoch [49/100] | MS-SSIM Loss: 0.1744 | Validation SSIM: 0.5737
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [50/100] | MS-SSIM Loss: 0.1736 | Validation SSIM: 0.5719
#    ⚠️ SSIM 未突破 (目前最佳: 0.5737)，停滯計數: 1/20
# Epoch [51/100] | MS-SSIM Loss: 0.1739 | Validation SSIM: 0.5718
#    ⚠️ SSIM 未突破 (目前最佳: 0.5737)，停滯計數: 2/20
# Epoch [52/100] | MS-SSIM Loss: 0.1742 | Validation SSIM: 0.5713
#    ⚠️ SSIM 未突破 (目前最佳: 0.5737)，停滯計數: 3/20
# Epoch [53/100] | MS-SSIM Loss: 0.1747 | Validation SSIM: 0.5702
#    ⚠️ SSIM 未突破 (目前最佳: 0.5737)，停滯計數: 4/20
# Epoch [54/100] | MS-SSIM Loss: 0.1742 | Validation SSIM: 0.5727
#    ⚠️ SSIM 未突破 (目前最佳: 0.5737)，停滯計數: 5/20
# Epoch [55/100] | MS-SSIM Loss: 0.1742 | Validation SSIM: 0.5741
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [56/100] | MS-SSIM Loss: 0.1738 | Validation SSIM: 0.5711
#    ⚠️ SSIM 未突破 (目前最佳: 0.5741)，停滯計數: 1/20
# Epoch [57/100] | MS-SSIM Loss: 0.1733 | Validation SSIM: 0.5731
#    ⚠️ SSIM 未突破 (目前最佳: 0.5741)，停滯計數: 2/20
# Epoch [58/100] | MS-SSIM Loss: 0.1733 | Validation SSIM: 0.5736
#    ⚠️ SSIM 未突破 (目前最佳: 0.5741)，停滯計數: 3/20
# Epoch [59/100] | MS-SSIM Loss: 0.1732 | Validation SSIM: 0.5716
#    ⚠️ SSIM 未突破 (目前最佳: 0.5741)，停滯計數: 4/20
# Epoch [60/100] | MS-SSIM Loss: 0.1728 | Validation SSIM: 0.5738
#    ⚠️ SSIM 未突破 (目前最佳: 0.5741)，停滯計數: 5/20
# Epoch [61/100] | MS-SSIM Loss: 0.1723 | Validation SSIM: 0.5747
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [62/100] | MS-SSIM Loss: 0.1721 | Validation SSIM: 0.5723
#    ⚠️ SSIM 未突破 (目前最佳: 0.5747)，停滯計數: 1/20
# Epoch [63/100] | MS-SSIM Loss: 0.1727 | Validation SSIM: 0.5720
#    ⚠️ SSIM 未突破 (目前最佳: 0.5747)，停滯計數: 2/20
# Epoch [64/100] | MS-SSIM Loss: 0.1731 | Validation SSIM: 0.5727
#    ⚠️ SSIM 未突破 (目前最佳: 0.5747)，停滯計數: 3/20
# Epoch [65/100] | MS-SSIM Loss: 0.1725 | Validation SSIM: 0.5747
#    ⚠️ SSIM 未突破 (目前最佳: 0.5747)，停滯計數: 4/20
# Epoch [66/100] | MS-SSIM Loss: 0.1720 | Validation SSIM: 0.5749
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [67/100] | MS-SSIM Loss: 0.1723 | Validation SSIM: 0.5728
#    ⚠️ SSIM 未突破 (目前最佳: 0.5749)，停滯計數: 1/20
# Epoch [68/100] | MS-SSIM Loss: 0.1723 | Validation SSIM: 0.5734
#    ⚠️ SSIM 未突破 (目前最佳: 0.5749)，停滯計數: 2/20
# Epoch [69/100] | MS-SSIM Loss: 0.1718 | Validation SSIM: 0.5744
#    ⚠️ SSIM 未突破 (目前最佳: 0.5749)，停滯計數: 3/20
# Epoch [70/100] | MS-SSIM Loss: 0.1726 | Validation SSIM: 0.5732
#    ⚠️ SSIM 未突破 (目前最佳: 0.5749)，停滯計數: 4/20
# Epoch [71/100] | MS-SSIM Loss: 0.1720 | Validation SSIM: 0.5732
#    ⚠️ SSIM 未突破 (目前最佳: 0.5749)，停滯計數: 5/20
# Epoch [72/100] | MS-SSIM Loss: 0.1713 | Validation SSIM: 0.5730
#    ⚠️ SSIM 未突破 (目前最佳: 0.5749)，停滯計數: 6/20
# Epoch [73/100] | MS-SSIM Loss: 0.1716 | Validation SSIM: 0.5747
#    ⚠️ SSIM 未突破 (目前最佳: 0.5749)，停滯計數: 7/20
# Epoch [74/100] | MS-SSIM Loss: 0.1715 | Validation SSIM: 0.5734
#    ⚠️ SSIM 未突破 (目前最佳: 0.5749)，停滯計數: 8/20
# Epoch [75/100] | MS-SSIM Loss: 0.1717 | Validation SSIM: 0.5769
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [76/100] | MS-SSIM Loss: 0.1712 | Validation SSIM: 0.5754
#    ⚠️ SSIM 未突破 (目前最佳: 0.5769)，停滯計數: 1/20
# Epoch [77/100] | MS-SSIM Loss: 0.1710 | Validation SSIM: 0.5739
#    ⚠️ SSIM 未突破 (目前最佳: 0.5769)，停滯計數: 2/20
# Epoch [78/100] | MS-SSIM Loss: 0.1713 | Validation SSIM: 0.5753
#    ⚠️ SSIM 未突破 (目前最佳: 0.5769)，停滯計數: 3/20
# Epoch [79/100] | MS-SSIM Loss: 0.1701 | Validation SSIM: 0.5760
#    ⚠️ SSIM 未突破 (目前最佳: 0.5769)，停滯計數: 4/20
# Epoch [80/100] | MS-SSIM Loss: 0.1702 | Validation SSIM: 0.5775
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [81/100] | MS-SSIM Loss: 0.1708 | Validation SSIM: 0.5748
#    ⚠️ SSIM 未突破 (目前最佳: 0.5775)，停滯計數: 1/20
# Epoch [82/100] | MS-SSIM Loss: 0.1704 | Validation SSIM: 0.5748
#    ⚠️ SSIM 未突破 (目前最佳: 0.5775)，停滯計數: 2/20
# Epoch [83/100] | MS-SSIM Loss: 0.1710 | Validation SSIM: 0.5761
#    ⚠️ SSIM 未突破 (目前最佳: 0.5775)，停滯計數: 3/20
# Epoch [84/100] | MS-SSIM Loss: 0.1707 | Validation SSIM: 0.5762
#    ⚠️ SSIM 未突破 (目前最佳: 0.5775)，停滯計數: 4/20
# Epoch [85/100] | MS-SSIM Loss: 0.1708 | Validation SSIM: 0.5759
#    ⚠️ SSIM 未突破 (目前最佳: 0.5775)，停滯計數: 5/20
# Epoch [86/100] | MS-SSIM Loss: 0.1712 | Validation SSIM: 0.5729
#    ⚠️ SSIM 未突破 (目前最佳: 0.5775)，停滯計數: 6/20
# Epoch [87/100] | MS-SSIM Loss: 0.1709 | Validation SSIM: 0.5763
#    ⚠️ SSIM 未突破 (目前最佳: 0.5775)，停滯計數: 7/20
# Epoch [88/100] | MS-SSIM Loss: 0.1707 | Validation SSIM: 0.5776
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [89/100] | MS-SSIM Loss: 0.1702 | Validation SSIM: 0.5773
#    ⚠️ SSIM 未突破 (目前最佳: 0.5776)，停滯計數: 1/20
# Epoch [90/100] | MS-SSIM Loss: 0.1697 | Validation SSIM: 0.5755
#    ⚠️ SSIM 未突破 (目前最佳: 0.5776)，停滯計數: 2/20
# Epoch [91/100] | MS-SSIM Loss: 0.1694 | Validation SSIM: 0.5773
#    ⚠️ SSIM 未突破 (目前最佳: 0.5776)，停滯計數: 3/20
# Epoch [92/100] | MS-SSIM Loss: 0.1694 | Validation SSIM: 0.5777
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [93/100] | MS-SSIM Loss: 0.1691 | Validation SSIM: 0.5772
#    ⚠️ SSIM 未突破 (目前最佳: 0.5777)，停滯計數: 1/20
# Epoch [94/100] | MS-SSIM Loss: 0.1694 | Validation SSIM: 0.5792
#    🌟 突破紀錄！已將最佳權重與 npz 測試包儲存至 PI_cGAN_V4_1_Balanced_results
# Epoch [95/100] | MS-SSIM Loss: 0.1693 | Validation SSIM: 0.5775
#    ⚠️ SSIM 未突破 (目前最佳: 0.5792)，停滯計數: 1/20
# Epoch [96/100] | MS-SSIM Loss: 0.1697 | Validation SSIM: 0.5760
#    ⚠️ SSIM 未突破 (目前最佳: 0.5792)，停滯計數: 2/20
# Epoch [97/100] | MS-SSIM Loss: 0.1700 | Validation SSIM: 0.5757
#    ⚠️ SSIM 未突破 (目前最佳: 0.5792)，停滯計數: 3/20
# Epoch [98/100] | MS-SSIM Loss: 0.1705 | Validation SSIM: 0.5748
#    ⚠️ SSIM 未突破 (目前最佳: 0.5792)，停滯計數: 4/20
# Epoch [99/100] | MS-SSIM Loss: 0.1696 | Validation SSIM: 0.5758
#    ⚠️ SSIM 未突破 (目前最佳: 0.5792)，停滯計數: 5/20
# Epoch [100/100] | MS-SSIM Loss: 0.1701 | Validation SSIM: 0.5759
#    ⚠️ SSIM 未突破 (目前最佳: 0.5792)，停滯計數: 6/20
#
# 🎉 V4.1 訓練大功告成！最佳成果已儲存在 PI_cGAN_V4_1_Balanced_results/v4_1_best_test_data.npz

# %%
import os
import glob
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
from IPython.display import clear_output
from tqdm.notebook import tqdm
from skimage.metrics import structural_similarity as ssim_metric

# ⚠️ 確保已經安裝 pytorch-msssim
try:
    from pytorch_msssim import ms_ssim
except ImportError:
    raise ImportError("請先在另一個 Cell 執行: !pip install pytorch-msssim")

# ==========================================
# 1. 環境設定與資料載入
# ==========================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"目前使用的運算裝置: {device}")

class DeepSpaceDataset(Dataset):
    def __init__(self, npz_folder):
        self.inputs = []
        self.targets = []
        file_paths = glob.glob(os.path.join(npz_folder, "*.npz"))
        for f in file_paths:
            data = np.load(f)
            self.inputs.append(data['inputs'])
            self.targets.append(data['targets'])
        self.inputs = np.concatenate(self.inputs, axis=0)
        self.targets = np.concatenate(self.targets, axis=0)
        self.inputs = np.expand_dims(self.inputs, axis=1)
        self.targets = np.expand_dims(self.targets, axis=1)

    def __len__(self):
        return self.inputs.shape[0]

    def __getitem__(self, idx):
        x = torch.tensor(self.inputs[idx], dtype=torch.float32)
        y = torch.tensor(self.targets[idx], dtype=torch.float32)
        x = (x - 0.5) / 0.55
        y = (y - 0.5) / 0.55
        x = torch.clamp(x, -1.0, 1.0)
        y = torch.clamp(y, -1.0, 1.0)
        return x, y

DATA_DIR = "processed_dataset"
full_dataset = DeepSpaceDataset(DATA_DIR)

dataset_size = len(full_dataset)
test_size = int(0.2 * dataset_size)
train_size = dataset_size - test_size

train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size], generator=torch.Generator().manual_seed(42))
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, drop_last=True)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False, drop_last=False)

# ==========================================
# 2. 神經網路架構 (完全不變)
# ==========================================
class UNetDown(nn.Module):
    def __init__(self, in_channels, out_channels, normalize=True, dropout=0.0):
        super().__init__()
        layers = [nn.Conv2d(in_channels, out_channels, kernel_size=4, stride=2, padding=1, bias=False)]
        if normalize:
            layers.append(nn.BatchNorm2d(out_channels))
        layers.append(nn.LeakyReLU(0.2))
        if dropout > 0.0:
            layers.append(nn.Dropout(dropout))
        self.model = nn.Sequential(*layers)
    def forward(self, x): return self.model(x)

class UNetUp(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=0.0):
        super().__init__()
        layers = [
            nn.ConvTranspose2d(in_channels, out_channels, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        ]
        if dropout > 0.0:
            layers.append(nn.Dropout(dropout))
        self.model = nn.Sequential(*layers)
    def forward(self, x, skip_input):
        x = self.model(x)
        return torch.cat((x, skip_input), 1)

class GeneratorUNet(nn.Module):
    def __init__(self, in_channels=1, out_channels=1):
        super().__init__()
        self.down1 = UNetDown(in_channels, 64, normalize=False)
        self.down2 = UNetDown(64, 128)
        self.down3 = UNetDown(128, 256)
        self.down4 = UNetDown(256, 512, dropout=0.5)
        self.down5 = UNetDown(512, 512, dropout=0.5)
        self.up1 = UNetUp(512, 512, dropout=0.5)
        self.up2 = UNetUp(1024, 256)
        self.up3 = UNetUp(512, 128)
        self.up4 = UNetUp(256, 64)
        self.final = nn.Sequential(nn.ConvTranspose2d(128, out_channels, kernel_size=4, stride=2, padding=1), nn.Tanh())
    def forward(self, x):
        d1 = self.down1(x)
        d2 = self.down2(d1)
        d3 = self.down3(d2)
        d4 = self.down4(d3)
        d5 = self.down5(d4)
        u1 = self.up1(d5, d4)
        u2 = self.up2(u1, d3)
        u3 = self.up3(u2, d2)
        u4 = self.up4(u3, d1)
        return self.final(u4)

class Discriminator(nn.Module):
    def __init__(self, in_channels=1):
        super().__init__()
        def discriminator_block(in_filters, out_filters, normalization=True):
            layers = [nn.Conv2d(in_filters, out_filters, 4, stride=2, padding=1)]
            if normalization: layers.append(nn.BatchNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers
        self.model = nn.Sequential(
            *discriminator_block(in_channels * 2, 64, normalization=False),
            *discriminator_block(64, 128),
            *discriminator_block(128, 256),
            *discriminator_block(256, 512),
            nn.Conv2d(512, 1, 4, padding=1, bias=False)
        )
    def forward(self, img_A, img_B):
        img_input = torch.cat((img_A, img_B), 1)
        return self.model(img_input)

# ==========================================
# 3. 物理引擎 V3 (參數 100% 照舊: lambda_flux=0.5)
# ==========================================
class PhysicsInformedLossV3(nn.Module):
    def __init__(self, lambda_pixel=100, lambda_fft=0.1, lambda_flux=0.5, asinh_a=0.1): 
        super().__init__()
        self.lambda_pixel = lambda_pixel
        self.lambda_fft = lambda_fft
        self.lambda_flux = lambda_flux
        self.criterion_l1 = nn.L1Loss()
        self.a = asinh_a
        self.arcsinh_1_over_a = np.arcsinh(1.0 / self.a)

    def inverse_transform_to_linear(self, tensor_img):
        y_original = (tensor_img * 0.55) + 0.5
        y_clamped = torch.clamp(y_original, 0.0, 1.0)
        return self.a * torch.sinh(y_clamped * self.arcsinh_1_over_a)

    def forward(self, generated, target):
        gen_linear = self.inverse_transform_to_linear(generated)
        target_linear = self.inverse_transform_to_linear(target)

        loss_pixel = self.criterion_l1(gen_linear, target_linear)
        
        fft_gen = torch.fft.fft2(generated, norm="ortho")
        fft_target = torch.fft.fft2(target, norm="ortho")
        loss_fft_real = self.criterion_l1(torch.real(fft_gen), torch.real(fft_target))
        loss_fft_imag = self.criterion_l1(torch.imag(fft_gen), torch.imag(fft_target))
        loss_fft = loss_fft_real + loss_fft_imag

        star_mask = (target > 0.0).float().detach() 
        flux_gen = torch.sum(gen_linear * star_mask, dim=(2, 3))
        flux_target = torch.sum(target_linear * star_mask, dim=(2, 3))
        loss_flux = self.criterion_l1(flux_gen, flux_target)

        total_pi_loss = (self.lambda_pixel * loss_pixel) + (self.lambda_fft * loss_fft) + (self.lambda_flux * loss_flux)
        return total_pi_loss, loss_pixel, loss_fft, loss_flux

# ==========================================
# 4. V4.1 【第二階段接力賽】環境設定
# ==========================================
# 🌟 修改 1：存到新的資料夾，保護你上一輪的完美存檔！
OUTPUT_PHASE2_DIR = "PI_cGAN_V4_1_Phase2_results"
os.makedirs(OUTPUT_PHASE2_DIR, exist_ok=True)
print(f"📁 已建立/確認接力賽專屬資料夾：{OUTPUT_PHASE2_DIR}")

generator_v4 = GeneratorUNet().to(device)
discriminator_v4 = Discriminator().to(device)

# 🌟 修改 2：起跑點改成你剛剛熱騰騰跑完的 V4.1 最佳權重
PREVIOUS_BEST_WEIGHTS = "PI_cGAN_V4_1_Balanced_results/v4_1_best_finetuned_weights.pth"
if os.path.exists(PREVIOUS_BEST_WEIGHTS):
    print(f"🧬 成功載入 V4.1 第一階段完美權重起跑：{PREVIOUS_BEST_WEIGHTS}")
    generator_v4.load_state_dict(torch.load(PREVIOUS_BEST_WEIGHTS, map_location=device))
else:
    print(f"⚠️ 找不到 {PREVIOUS_BEST_WEIGHTS}，請確認上一輪的資料夾路徑正確！")

LR_V4 = 0.00002  
optimizer_G_v4 = optim.Adam(generator_v4.parameters(), lr=LR_V4, betas=(0.5, 0.999))
optimizer_D_v4 = optim.Adam(discriminator_v4.parameters(), lr=LR_V4, betas=(0.5, 0.999))

pi_criterion_v4 = PhysicsInformedLossV3().to(device)
criterion_GAN_v4 = nn.BCEWithLogitsLoss().to(device)

# ==========================================
# 5. V4.1 第二階段接力訓練迴圈
# ==========================================
epochs_v4 = 100
best_val_ssim = 0.0
patience = 30  # 🌟 修改 3：既然是收斂末期，耐心值給多一點，容許它稍微震盪
no_improve_count = 0

print("🔥 V4.1 第二階段接力賽正式啟動：所有權重參數 100% 照舊，繼續朝極限推進！")

for epoch in range(epochs_v4):
    generator_v4.train()
    discriminator_v4.train()
    epoch_ms_ssim_loss = 0.0
    
    for i, (real_A, real_B) in enumerate(train_dataloader):
        real_A, real_B = real_A.to(device), real_B.to(device)

        # Generator
        optimizer_G_v4.zero_grad()
        fake_B = generator_v4(real_A)
        
        pred_fake = discriminator_v4(real_A, fake_B)
        loss_GAN = criterion_GAN_v4(pred_fake, torch.ones_like(pred_fake, device=device))
        
        # 物理約束
        total_pi_loss, _, _, _ = pi_criterion_v4(fake_B, real_B)
        
        # MS-SSIM Loss
        gen_01 = (fake_B + 1.0) / 2.0
        real_01 = (real_B + 1.0) / 2.0
        loss_msssim = 1 - ms_ssim(gen_01, real_01, data_range=1.0, size_average=True)
        
        # 🌟 參數 100% 照舊：MS-SSIM 權重依然是 15
        loss_G = loss_GAN + total_pi_loss + (15 * loss_msssim)
        loss_G.backward()
        optimizer_G_v4.step()
        
        epoch_ms_ssim_loss += loss_msssim.item()

        # Discriminator
        optimizer_D_v4.zero_grad()
        pred_real = discriminator_v4(real_A, real_B)
        loss_real = criterion_GAN_v4(pred_real, torch.ones_like(pred_real))
        pred_fake_detach = discriminator_v4(real_A, fake_B.detach())
        loss_fake = criterion_GAN_v4(pred_fake_detach, torch.zeros_like(pred_fake_detach))
        loss_D = 0.5 * (loss_real + loss_fake)
        loss_D.backward()
        optimizer_D_v4.step()

    # ---------- 驗證階段 ----------
    generator_v4.eval()
    val_ssim_list = []
    
    with torch.no_grad():
        for test_A, test_B in test_dataloader:
            test_A, test_B = test_A.to(device), test_B.to(device)
            test_fake_B = generator_v4(test_A)
            
            np_fake = test_fake_B.cpu().numpy()
            np_real = test_B.cpu().numpy()
            for b in range(np_fake.shape[0]):
                val_ssim_list.append(ssim_metric(np_real[b, 0], np_fake[b, 0], data_range=2.0))
                
        current_epoch_ssim = np.mean(val_ssim_list)
    
    # 🌟 為了不讓你覺得它退步，我們讓它顯示絕對圈數 (例如 Epoch 101/200)
    print(f"Epoch [{epoch+101}/{epochs_v4+100}] | MS-SSIM Loss: {epoch_ms_ssim_loss/len(train_dataloader):.4f} | Validation SSIM: {current_epoch_ssim:.4f}")
    
    if current_epoch_ssim > best_val_ssim:
        best_val_ssim = current_epoch_ssim
        no_improve_count = 0
        
        best_pth_path = os.path.join(OUTPUT_PHASE2_DIR, "v4_1_phase2_best_weights.pth")
        torch.save(generator_v4.state_dict(), best_pth_path)
        
        best_npz_path = os.path.join(OUTPUT_PHASE2_DIR, "v4_1_phase2_best_test_data.npz")
        test_A_sample, test_B_sample = next(iter(test_dataloader))
        test_fake_sample = generator_v4(test_A_sample.to(device))
        np.savez_compressed(best_npz_path, 
                            inputs=test_A_sample.cpu().numpy(), 
                            targets=test_B_sample.cpu().numpy(), 
                            generated=test_fake_sample.detach().cpu().numpy())
        
        print(f"   🌟 突破紀錄！已將接力賽最佳權重與 npz 儲存至 {OUTPUT_PHASE2_DIR}")
    else:
        no_improve_count += 1
        print(f"   ⚠️ SSIM 未突破 (目前接力賽最佳: {best_val_ssim:.4f})，停滯計數: {no_improve_count}/{patience}")
        
    if no_improve_count >= patience:
        print(f"\n🛑 觸發早停！連續 {patience} 圈未突破，代表模型已達極限，訓練結束。")
        break

print(f"\n🎉 V4.1 第二階段接力賽大功告成！最佳成果已儲存在 {OUTPUT_PHASE2_DIR}/v4_1_phase2_best_test_data.npz")
# Out:
# 目前使用的運算裝置: cuda
# 📁 已建立/確認接力賽專屬資料夾：PI_cGAN_V4_1_Phase2_results
# 🧬 成功載入 V4.1 第一階段完美權重起跑：PI_cGAN_V4_1_Balanced_results/v4_1_best_finetuned_weights.pth
# 🔥 V4.1 第二階段接力賽正式啟動：所有權重參數 100% 照舊，繼續朝極限推進！
# Epoch [101/200] | MS-SSIM Loss: 0.1680 | Validation SSIM: 0.5795
#    🌟 突破紀錄！已將接力賽最佳權重與 npz 儲存至 PI_cGAN_V4_1_Phase2_results
# Epoch [102/200] | MS-SSIM Loss: 0.1647 | Validation SSIM: 0.5800
#    🌟 突破紀錄！已將接力賽最佳權重與 npz 儲存至 PI_cGAN_V4_1_Phase2_results
# Epoch [103/200] | MS-SSIM Loss: 0.1621 | Validation SSIM: 0.5794
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5800)，停滯計數: 1/30
# Epoch [104/200] | MS-SSIM Loss: 0.1601 | Validation SSIM: 0.5804
#    🌟 突破紀錄！已將接力賽最佳權重與 npz 儲存至 PI_cGAN_V4_1_Phase2_results
# Epoch [105/200] | MS-SSIM Loss: 0.1592 | Validation SSIM: 0.5784
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5804)，停滯計數: 1/30
# Epoch [106/200] | MS-SSIM Loss: 0.1588 | Validation SSIM: 0.5776
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5804)，停滯計數: 2/30
# Epoch [107/200] | MS-SSIM Loss: 0.1590 | Validation SSIM: 0.5769
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5804)，停滯計數: 3/30
# Epoch [108/200] | MS-SSIM Loss: 0.1608 | Validation SSIM: 0.5734
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5804)，停滯計數: 4/30
# Epoch [109/200] | MS-SSIM Loss: 0.1630 | Validation SSIM: 0.5764
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5804)，停滯計數: 5/30
# Epoch [110/200] | MS-SSIM Loss: 0.1647 | Validation SSIM: 0.5762
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5804)，停滯計數: 6/30
# Epoch [111/200] | MS-SSIM Loss: 0.1659 | Validation SSIM: 0.5787
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5804)，停滯計數: 7/30
# Epoch [112/200] | MS-SSIM Loss: 0.1670 | Validation SSIM: 0.5791
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5804)，停滯計數: 8/30
# Epoch [113/200] | MS-SSIM Loss: 0.1683 | Validation SSIM: 0.5808
#    🌟 突破紀錄！已將接力賽最佳權重與 npz 儲存至 PI_cGAN_V4_1_Phase2_results
# Epoch [114/200] | MS-SSIM Loss: 0.1675 | Validation SSIM: 0.5835
#    🌟 突破紀錄！已將接力賽最佳權重與 npz 儲存至 PI_cGAN_V4_1_Phase2_results
# Epoch [115/200] | MS-SSIM Loss: 0.1662 | Validation SSIM: 0.5826
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5835)，停滯計數: 1/30
# Epoch [116/200] | MS-SSIM Loss: 0.1653 | Validation SSIM: 0.5814
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5835)，停滯計數: 2/30
# Epoch [117/200] | MS-SSIM Loss: 0.1644 | Validation SSIM: 0.5837
#    🌟 突破紀錄！已將接力賽最佳權重與 npz 儲存至 PI_cGAN_V4_1_Phase2_results
# Epoch [118/200] | MS-SSIM Loss: 0.1642 | Validation SSIM: 0.5836
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 1/30
# Epoch [119/200] | MS-SSIM Loss: 0.1641 | Validation SSIM: 0.5804
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 2/30
# Epoch [120/200] | MS-SSIM Loss: 0.1643 | Validation SSIM: 0.5832
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 3/30
# Epoch [121/200] | MS-SSIM Loss: 0.1644 | Validation SSIM: 0.5825
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 4/30
# Epoch [122/200] | MS-SSIM Loss: 0.1638 | Validation SSIM: 0.5822
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 5/30
# Epoch [123/200] | MS-SSIM Loss: 0.1642 | Validation SSIM: 0.5802
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 6/30
# Epoch [124/200] | MS-SSIM Loss: 0.1638 | Validation SSIM: 0.5790
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 7/30
# Epoch [125/200] | MS-SSIM Loss: 0.1638 | Validation SSIM: 0.5796
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 8/30
# Epoch [126/200] | MS-SSIM Loss: 0.1634 | Validation SSIM: 0.5812
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 9/30
# Epoch [127/200] | MS-SSIM Loss: 0.1647 | Validation SSIM: 0.5799
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 10/30
# Epoch [128/200] | MS-SSIM Loss: 0.1645 | Validation SSIM: 0.5761
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 11/30
# Epoch [129/200] | MS-SSIM Loss: 0.1648 | Validation SSIM: 0.5809
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 12/30
# Epoch [130/200] | MS-SSIM Loss: 0.1646 | Validation SSIM: 0.5802
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 13/30
# Epoch [131/200] | MS-SSIM Loss: 0.1654 | Validation SSIM: 0.5793
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 14/30
# Epoch [132/200] | MS-SSIM Loss: 0.1658 | Validation SSIM: 0.5762
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 15/30
# Epoch [133/200] | MS-SSIM Loss: 0.1659 | Validation SSIM: 0.5777
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 16/30
# Epoch [134/200] | MS-SSIM Loss: 0.1661 | Validation SSIM: 0.5790
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 17/30
# Epoch [135/200] | MS-SSIM Loss: 0.1668 | Validation SSIM: 0.5790
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 18/30
# Epoch [136/200] | MS-SSIM Loss: 0.1651 | Validation SSIM: 0.5755
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 19/30
# Epoch [137/200] | MS-SSIM Loss: 0.1659 | Validation SSIM: 0.5763
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 20/30
# Epoch [138/200] | MS-SSIM Loss: 0.1667 | Validation SSIM: 0.5760
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 21/30
# Epoch [139/200] | MS-SSIM Loss: 0.1667 | Validation SSIM: 0.5754
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 22/30
# Epoch [140/200] | MS-SSIM Loss: 0.1667 | Validation SSIM: 0.5781
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 23/30
# Epoch [141/200] | MS-SSIM Loss: 0.1680 | Validation SSIM: 0.5774
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 24/30
# Epoch [142/200] | MS-SSIM Loss: 0.1678 | Validation SSIM: 0.5768
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 25/30
# Epoch [143/200] | MS-SSIM Loss: 0.1668 | Validation SSIM: 0.5757
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 26/30
# Epoch [144/200] | MS-SSIM Loss: 0.1666 | Validation SSIM: 0.5755
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 27/30
# Epoch [145/200] | MS-SSIM Loss: 0.1677 | Validation SSIM: 0.5765
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 28/30
# Epoch [146/200] | MS-SSIM Loss: 0.1677 | Validation SSIM: 0.5756
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 29/30
# Epoch [147/200] | MS-SSIM Loss: 0.1672 | Validation SSIM: 0.5764
#    ⚠️ SSIM 未突破 (目前接力賽最佳: 0.5837)，停滯計數: 30/30
#
# 🛑 觸發早停！連續 30 圈未突破，代表模型已達極限，訓練結束。
#
# 🎉 V4.1 第二階段接力賽大功告成！最佳成果已儲存在 PI_cGAN_V4_1_Phase2_results/v4_1_phase2_best_test_data.npz

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim

# 1. 🌟 改為讀取 V4.1 專屬資料夾
file_path = "PI_cGAN_V4_1_Phase2_results/v4_1_phase2_best_test_data.npz"
data = np.load(file_path)

inputs = data['inputs']
targets = data['targets']
generated = data['generated']

num_images, _, h, w = inputs.shape
print(f"📊 總共載入 {num_images} 張 PI-cGAN V4.1 測試圖片進行分析...")

# ==========================================
# 預先計算半徑矩陣
# ==========================================
center = (int(h/2), int(w/2))
y, x = np.indices((h, w))
r_matrix = np.sqrt((x - center[1])**2 + (y - center[0])**2).astype(int)
nr = np.bincount(r_matrix.ravel())

# ==========================================
# 計算單張 RAPS
# ==========================================
def calculate_raps_fast(image):
    f_transform = np.fft.fft2(image)
    f_shift = np.fft.fftshift(f_transform)
    power_spectrum = np.abs(f_shift)**2
    tbin = np.bincount(r_matrix.ravel(), power_spectrum.ravel())
    radialprofile = tbin / nr
    return radialprofile

# ==========================================
# 2. 計算 RAPS 與 圖像指標
# ==========================================
all_raps_in, all_raps_gt, all_raps_gen = [], [], []
psnr_gen_list, ssim_gen_list = [], []

print("⚙️ 正在計算 V4.1 空間域指標與頻域 RAPS 特徵...")
for i in range(num_images):
    img_in = inputs[i, 0]
    img_gt = targets[i, 0]
    img_gen = generated[i, 0]
    
    all_raps_in.append(calculate_raps_fast(img_in))
    all_raps_gt.append(calculate_raps_fast(img_gt))
    all_raps_gen.append(calculate_raps_fast(img_gen))
    
    psnr_val = psnr(img_gt, img_gen, data_range=2.0)
    ssim_val = ssim(img_gt, img_gen, data_range=2.0)
    psnr_gen_list.append(psnr_val)
    ssim_gen_list.append(ssim_val)

mean_raps_in = np.mean(all_raps_in, axis=0)
mean_raps_gt = np.mean(all_raps_gt, axis=0)
mean_raps_gen = np.mean(all_raps_gen, axis=0)

std_raps_gt = np.std(all_raps_gt, axis=0)
std_raps_gen = np.std(all_raps_gen, axis=0)

freq_len = len(mean_raps_gt) // 2
x_freq = np.arange(freq_len)

mean_psnr = np.mean(psnr_gen_list)
mean_ssim = np.mean(ssim_gen_list)

# ==========================================
# 繪圖視覺化
# ==========================================
fig = plt.figure(figsize=(16, 10))

display_idx = 0 
ax1 = plt.subplot(2, 3, 1)
ax1.imshow(inputs[display_idx, 0], cmap='magma', origin='lower', vmin=-1, vmax=1)
ax1.set_title(f"Input (Degraded)")
ax1.axis('off')

ax2 = plt.subplot(2, 3, 2)
ax2.imshow(targets[display_idx, 0], cmap='magma', origin='lower', vmin=-1, vmax=1)
ax2.set_title(f"Ground Truth")
ax2.axis('off')

ax3 = plt.subplot(2, 3, 3)
ax3.imshow(generated[display_idx, 0], cmap='magma', origin='lower', vmin=-1, vmax=1)
ax3.set_title(f"PI-cGAN V4 Output\n(PSNR: {psnr_gen_list[display_idx]:.2f} | SSIM: {ssim_gen_list[display_idx]:.3f})")
ax3.axis('off')

ax4 = plt.subplot(2, 1, 2)
ax4.plot(x_freq, mean_raps_gt[:freq_len], label='Ground Truth', linewidth=2, color='#1f77b4')
ax4.fill_between(x_freq, 
                 np.maximum(mean_raps_gt[:freq_len] - std_raps_gt[:freq_len], 1e-10), 
                 mean_raps_gt[:freq_len] + std_raps_gt[:freq_len], 
                 color='#1f77b4', alpha=0.2)

ax4.plot(x_freq, mean_raps_gen[:freq_len], label='PI-cGAN V4 Output', linewidth=2, color='#2ca02c')
ax4.fill_between(x_freq, 
                 np.maximum(mean_raps_gen[:freq_len] - std_raps_gen[:freq_len], 1e-10), 
                 mean_raps_gen[:freq_len] + std_raps_gen[:freq_len], 
                 color='#2ca02c', alpha=0.2)

ax4.plot(x_freq, mean_raps_in[:freq_len], label='Input (Degraded)', alpha=0.6, linestyle=':', color='gray')

ax4.set_yscale('log')
ax4.set_title(f"PI-cGAN V4.1 Mean RAPS Analysis (Avg PSNR: {mean_psnr:.2f} dB, Avg SSIM: {mean_ssim:.4f})", fontsize=15, fontweight='bold')
ax4.set_xlabel("Spatial Frequency (Low -> High)", fontsize=13)
ax4.set_ylabel("Power Spectrum (Log Scale)", fontsize=13)
ax4.legend(fontsize=12, loc='lower left')
ax4.grid(True, which="both", ls="--", alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# 📊 總共載入 16 張 PI-cGAN V4.1 測試圖片進行分析...
# ⚙️ 正在計算 V4.1 空間域指標與頻域 RAPS 特徵...

# %%
import numpy as np
import matplotlib.pyplot as plt

# 🌟 讀取 V4 數據
file_path = "PI_cGAN_V4_1_Phase2_results/v4_1_phase2_best_test_data.npz"
data = np.load(file_path)

inputs = data['inputs']
targets = data['targets']
generated = data['generated']
num_images = inputs.shape[0]

print("⚙️ 正在計算 V4.1 傅立葉相位誤差與【線性物理空間】光通量守恆...")

def calculate_phase(image):
    f_transform = np.fft.fft2(image)
    f_shift = np.fft.fftshift(f_transform)
    return np.angle(f_shift)

# 計算 Phase MSE
phase_mse_list = []
for i in range(num_images):
    phase_gt = calculate_phase(targets[i, 0])
    phase_gen = calculate_phase(generated[i, 0])
    phase_diff = np.angle(np.exp(1j * (phase_gt - phase_gen)))
    phase_mse = np.mean(phase_diff**2)
    phase_mse_list.append(phase_mse)

mean_phase_mse = np.mean(phase_mse_list)

# ==========================================
# 🌟 保留核心修正：對齊逆轉換公式 (0.55)
# ==========================================
flux_gt_list = []
flux_gen_list = []

a = 0.1
arcsinh_1_over_a = np.arcsinh(1.0 / a)

for i in range(num_images):
    img_gt = targets[i, 0]
    img_gen = generated[i, 0]
    
    # 映射比例退回 [0, 1] 並加上 Clamp 避免極端值
    gt_01 = np.clip((img_gt * 0.55) + 0.5, 0.0, 1.0)
    gen_01 = np.clip((img_gen * 0.55) + 0.5, 0.0, 1.0)
    
    # 逆推回真實線性物理空間 (Linear Physical Space)
    gt_linear = a * np.sinh(gt_01 * arcsinh_1_over_a)
    gen_linear = a * np.sinh(gen_01 * arcsinh_1_over_a)
    
    # 在線性空間用嚴格的 1e-4 當作遮罩 (過濾純背景)
    star_mask = gt_linear > 1e-4
    
    flux_gt = np.sum(gt_linear[star_mask])
    flux_gen = np.sum(gen_linear[star_mask])
    
    if flux_gt > 1e-5:
        flux_gt_list.append(flux_gt)
        flux_gen_list.append(flux_gen)

flux_gt_arr = np.array(flux_gt_list)
flux_gen_arr = np.array(flux_gen_list)

# 計算線性物理空間的真實誤差
flux_mape = np.mean(np.abs(flux_gt_arr - flux_gen_arr) / flux_gt_arr) * 100

# 開始繪圖
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

display_idx = 0
phase_gt_sample = calculate_phase(targets[display_idx, 0])
phase_gen_sample = calculate_phase(generated[display_idx, 0])
phase_diff_sample = np.angle(np.exp(1j * (phase_gt_sample - phase_gen_sample)))

im1 = axes[0].imshow(phase_diff_sample, cmap='twilight', vmin=-np.pi, vmax=np.pi)
axes[0].set_title(f"PI-cGAN V4 Phase Difference Map\n(Dataset Avg Phase MSE: {mean_phase_mse:.4f})", fontsize=14)
axes[0].axis('off')
cbar = fig.colorbar(im1, ax=axes[0], fraction=0.046, pad=0.04)
cbar.set_label('Phase Error (Radians)', rotation=270, labelpad=15)

# 右圖散佈圖
axes[1].scatter(flux_gt_arr, flux_gen_arr, alpha=0.8, color='#2ca02c', marker='^', edgecolors='k', label='PI-cGAN V4 vs Truth')

max_flux = max(np.max(flux_gt_arr), np.max(flux_gen_arr))
min_flux = min(np.min(flux_gt_arr), np.min(flux_gen_arr))
axes[1].plot([min_flux, max_flux], [min_flux, max_flux], 'b--', linewidth=2, label='Ideal Conservation (y=x)')

axes[1].set_title(f"True Physical Flux Conservation (Linear Space)\n(Mean Absolute Error: {flux_mape:.2f}%)", fontsize=14)
axes[1].set_xlabel("Ground Truth Physical Flux", fontsize=12)
axes[1].set_ylabel("Generated Output Physical Flux", fontsize=12)
axes[1].legend(fontsize=12)
axes[1].grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# ⚙️ 正在計算 V4.1 傅立葉相位誤差與【線性物理空間】光通量守恆...

# %%
import numpy as np
import pandas as pd
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from IPython.display import display

# 🌟 讀取 V4 數據
file_path = "PI_cGAN_V4_1_Phase2_results/v4_1_phase2_best_test_data.npz"
data = np.load(file_path)

inputs = data['inputs']
targets = data['targets']
generated = data['generated']
num_images = inputs.shape[0]

print(f"📦 成功載入 {num_images} 張圖片，準備產出 V4.1 最終數據報表...")

all_metrics = []
a = 0.1
arcsinh_1_over_a = np.arcsinh(1.0 / a)

for i in range(num_images):
    img_in = inputs[i, 0]
    img_gt = targets[i, 0]
    img_gen = generated[i, 0]
    
    psnr_val = psnr(img_gt, img_gen, data_range=2.0)
    ssim_val = ssim(img_gt, img_gen, data_range=2.0)
    
    phase_gt = np.angle(np.fft.fftshift(np.fft.fft2(img_gt)))
    phase_gen = np.angle(np.fft.fftshift(np.fft.fft2(img_gen)))
    phase_diff = np.angle(np.exp(1j * (phase_gt - phase_gen)))
    phase_mse = np.mean(phase_diff**2)
    
    # 🌟 核心修正：對齊逆轉換公式 (0.55)
    gt_01 = np.clip((img_gt * 0.55) + 0.5, 0.0, 1.0)
    gen_01 = np.clip((img_gen * 0.55) + 0.5, 0.0, 1.0)
    
    gt_linear = a * np.sinh(gt_01 * arcsinh_1_over_a)
    gen_linear = a * np.sinh(gen_01 * arcsinh_1_over_a)
    
    star_mask = gt_linear > 1e-4
    
    flux_gt = np.sum(gt_linear[star_mask])
    flux_gen = np.sum(gen_linear[star_mask])
    
    if flux_gt > 1e-5:
        flux_error_percent = np.abs(flux_gt - flux_gen) / flux_gt * 100
    else:
        flux_error_percent = np.nan 
        
    all_metrics.append({
        "Image_ID": f"Test_Sample_{i:02d}",
        "PSNR (dB)": round(psnr_val, 4),
        "SSIM": round(ssim_val, 4),
        "Phase_MSE (rad)": round(phase_mse, 4),
        "GT_Linear_Flux": round(flux_gt, 2),
        "Gen_Linear_Flux": round(flux_gen, 2),
        "Linear_Flux_Error (%)": round(flux_error_percent, 2)
    })

df_metrics = pd.DataFrame(all_metrics)

mean_values = df_metrics.mean(numeric_only=True).round(4)
mean_row = pd.DataFrame([mean_values])
mean_row.insert(0, "Image_ID", "PI-cGAN_V4_AVERAGE")

df_final = pd.concat([df_metrics, mean_row], ignore_index=True)

# 🌟 存檔至 V4 資料夾
output_csv_path = "PI_cGAN_V4_1_Phase2_results/picgan_v4.1_metrics_report.csv"
df_final.to_csv(output_csv_path, index=False, encoding='utf-8-sig')

print(f"✅ V4.1 報表萃取完成！已成功匯出至：{output_csv_path}")
display(df_final.tail())
# Out:
# 📦 成功載入 16 張圖片，準備產出 V4.1 最終數據報表...
# ✅ V4.1 報表萃取完成！已成功匯出至：PI_cGAN_V4_1_Phase2_results/picgan_v4.1_metrics_report.csv
#               Image_ID  PSNR (dB)    SSIM  Phase_MSE (rad)  GT_Linear_Flux  \
# 12      Test_Sample_12    16.1878  0.1159           3.0890      11269.9900
# 13      Test_Sample_13    32.8819  0.9152           2.7096        158.8800
# 14      Test_Sample_14    14.7941  0.0541           3.1686      11340.8400
# 15      Test_Sample_15    25.8866  0.8458           2.2718       5105.3400
# 16  PI-cGAN_V4_AVERAGE    22.6105  0.4921           2.7845       7087.3662
#
#     Gen_Linear_Flux  Linear_Flux_Error (%)
# 12       13041.4500                15.7200
# 13         303.4200                90.9700
# 14       13725.3000                21.0300
# 15        5111.4600                 0.1200
# 16        7575.0544                10.5356
